# %%
# !pip install torchtext

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from torch.nn.utils.rnn import pad_sequence

import string as st

import nltk
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import torchtext
from torchtext.data import get_tokenizer
from torchtext.vocab import GloVe
from torchtext import data
from torchtext import vocab

# %%
import csv
yelp_path_train="/content/drive/MyDrive/yelp_train.csv"
yelp_path_test="/content/drive/MyDrive/yelp_test.csv"
train_dataset = pd.read_csv(yelp_path_train)
test_dataset = pd.read_csv(yelp_path_test)
train_texts = train_dataset['text'].apply(str.lower)
train_labels = train_dataset['stars'].apply(lambda x: x - 1)
test_texts = test_dataset['text'].apply(str.lower)
test_labels = test_dataset['stars'].apply(lambda x: x - 1)

# %%
print(train_texts[0])
# Out:
# in general very good buffet for the price..nice little sushi bar ..crab legs and such. i highly recommend if u like chinese  buffet ..

# %%
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
unique_words = set()
X_train = []

for document in train_texts:
    sentences = sent_tokenize(document)
    document_tokens = []

    for sentence in sentences:
        tokens = word_tokenize(sentence)
        document_tokens.append(tokens)
        unique_words.update(tokens)
    X_train.append(document_tokens)
X_test=[]
for document in test_texts:
    sentences = sent_tokenize(document)
    document_tokens = []

    for sentence in sentences:
        tokens = word_tokenize(sentence)
        document_tokens.append(tokens)
        unique_words.update(tokens)
    X_test.append(document_tokens)
print(X_train[0])
# Out:
# [['in', 'general', 'very', 'good', 'buffet', 'for', 'the', 'price', '..', 'nice', 'little', 'sushi', 'bar', '..', 'crab', 'legs', 'and', 'such', '.'], ['i', 'highly', 'recommend', 'if', 'u', 'like', 'chinese', 'buffet', '..']]

# %%
print(unique_words)
# Out:
# {'evergreen', 'livable', 'eggplant', 'dried', 'harris', 'prices-very', 'non', 'amenities', 'off-base', 'cramped', 'booth', 'belt', 'winking', 'presentation', 'skimpy', 'mozz', 'pictures', 'scented', 'color', 'climbing', 'scale', 'deducted', 'minuses', 'hatch', 'brainer', 'abberation', 'blow', 'lie', 'marbelade', 'nigiri', 'chain', 'allergy', 'aggressive', 'dinner', 'bs', 'standard', 'feta', 'sourdough', 'myriad', 'regal', 'coulter', 'disease', 'fifa', 'suggestions', 'huffed', 'budget', 'appropriate', 'mistake', 'jaw/mouth', 'civilized', 'separation', 'thin', 'falafel', 'cats', 'reopen', 'pizzas', 'sooooo', 'furnishings', 'artichoke', 'baba', 'carmen', 'blocks', 'systems', 'amazed', 'darren', 'june', 'peculiar', 'loud', 'zesty', 'melrose', 'gesture', 'thanks', 'polpette', 'cars', 'harvard', 'missing', 'dislodged', 'crispiness', 'possibility', 'scenes', 'lasagnette', 'act', '2013.', 'welcoming', 'burger', 'six', 'synopsis', 'waist', 'drops', 'razor', '922', 'checking', 'choices', 'ful', 'abrupt', 'admit', 'core', 'temporary', 'lunchtime/dinner', 'accent', 'stonecrest', 'sparkle', 'stew', 'raging', 'side-dish', 'learning', 'troopers', 'servicing', 'mate', 'breadcrumbs', 'doughy', 'cuticles', 'upholding', '2018', 'pandora', 'shone', 'offseason', 'orthotics', 'session', 'keratin', 'river', 'stayed', 'long', 'optional', 'squirrel', 'stuffed', 'brew', 'oriented', 'wipe', 'creating', 'maid', 'listen', 'fancy', 'cancellation', 'full', 'ship', 'tenderloin', 'bangs', 'houses', 'soon', 'feels', 'childhood', '75', 'stands', 'muscles', 'burden', 'shoot', 'nickel', 'mostly', 'presses', 'abc', 'brining', 'ringer', 'complete', 'crapy', 'wuss', 'covered', 'fantastic', 'ponzu', 'unlimited', 'band', 'cuts', 'settings', 'crescent', 'i', 'investigate', 'soju', 'assured', 'abroad', 'chewy', 'wong', 'iowa', 'cant', 'kfc', 'disorder', 'expect', 'twists', '12:30', 'new/additional', 'patrick', 'mesquite', 'won', 'omit', 'cobbler', 'tho', 'fixed', 'present', 'check-ins', 'morton', 'motion', 'denver', 'holiday', 'gets', 'cons', 'garden', 'randomly', 'resolved', '1may2017', 'thanked', 'trough', 'wo', 'tvs', 'concern', 'curbing', 'stab', 'clerical', 'meeting', 'invaluable', 'supplements', 'indoor', 'pre-packaged', 'overzealous', 'ladies', 'dodgeball', 'march', 'side', 'mandalay', 'you-trim', 'wall', 'policy', 'source', 'politely', 'pizza', 'bunny', 'uni-brow', 'poorly', 'correct', 'itself', 'drained', 'harder', 'upon', 'boost', 'fountain', 'staff', 'arms', 'crushed', 'cosmo', 'strawberry', 'combo-', 'pros', 'sake', 'subpar', 'list', 'formed', '@', 'watch', 'paintings', 'boxes', 'waxing', 'participate', 'generally', 'fucking', 'drama', 'task', 'awakened', 'two-tatted', 'replicate', 'struggle', 'el', 'timbuktu', 'carpe', 'undertone', 'cheaper', 'smelly', 'kale', 'sin', 'ginza', 'separates', 'refrigeration', 'cutest', 'trista', 'y', 'taxi', 'hits', 'downgraded', '8-', '50min', 'corral', 'unavailable', 'fuente', 'extreme', 'repeated', '7pm', 'southeast', 'lots', 'spoiled', 'promise', '2010.', 'artwork', 'decatur', 'chops', 'roped', 'crispy', 'ours', 'guacamole', 'walks', '3-5pm', 'bask', '4:30-6:30', 'tonight', 'zinger', 'customer', 'une', 'spoons', 'lose', 'airbnb', 'laying', 'stacked', 'harbour', 'disgusted', 'hoping', 'gentle', 'crave', 'dragon', 'dot', 'recitation', 'challenging', '7am-10am', 'diagnosing', 'menus', 'aunt', 'bed', 'ever', 'reschedule', 'call', 'men', 'dentist', '.10', 'bottom', 'sold', 'asia', 'liking', 'jamie', 'ganouj', 'moishe', 'refunded', 'saint-paul', 'id', 'bianca', 'sandwich', 'convinced', 'at', 'person', 'hefe', 'orders', 'cartridges', 'worked', 'milestones', 'exploring', 'share', 'firmer', 'cs', 'adamantly', 'ex', 'abfab', 'ribeye', 'trying', 'always', 'crazy', 'some', 'seats', 'rotary', 'leslieville', 'draining', 'crowed', 'views', 'raisin', 'matter', 'walk', 'remove', 'haji', 'rambled', 'so-so', 'nailed', '17', 'narrowed', 'vie', 'fashipn', 'bold', 'jealously', 'chip', 'word', 'significantly', 'yrs', 'elongation', 'spare', 'beets ...

# %%
unique_words = list(unique_words)
print("Corpus size:", len(unique_words))

embedding_dim = 100
global_vectors = GloVe(name='6B', dim=embedding_dim) # 42B, 840B

corpus_size = len(unique_words)
weights_matrix = np.zeros((corpus_size, embedding_dim))

found_word = 0
for i, word in enumerate(unique_words):
  word_vector = global_vectors.get_vecs_by_tokens(word)

  if word_vector.sum().item() == '0':
    weights_matrix[i] = np.random.normal(scale=0.6, size=(embedding_dim, ))
  else:
    weights_matrix[i] = word_vector
    found_word += 1
# Out:
# Corpus size: 8337

# %%
print(unique_words)
# Out:
# ['evergreen', 'livable', 'eggplant', 'dried', 'harris', 'prices-very', 'non', 'amenities', 'off-base', 'cramped', 'booth', 'belt', 'winking', 'presentation', 'skimpy', 'mozz', 'pictures', 'scented', 'color', 'climbing', 'scale', 'deducted', 'minuses', 'hatch', 'brainer', 'abberation', 'blow', 'lie', 'marbelade', 'nigiri', 'chain', 'allergy', 'aggressive', 'dinner', 'bs', 'standard', 'feta', 'sourdough', 'myriad', 'regal', 'coulter', 'disease', 'fifa', 'suggestions', 'huffed', 'budget', 'appropriate', 'mistake', 'jaw/mouth', 'civilized', 'separation', 'thin', 'falafel', 'cats', 'reopen', 'pizzas', 'sooooo', 'furnishings', 'artichoke', 'baba', 'carmen', 'blocks', 'systems', 'amazed', 'darren', 'june', 'peculiar', 'loud', 'zesty', 'melrose', 'gesture', 'thanks', 'polpette', 'cars', 'harvard', 'missing', 'dislodged', 'crispiness', 'possibility', 'scenes', 'lasagnette', 'act', '2013.', 'welcoming', 'burger', 'six', 'synopsis', 'waist', 'drops', 'razor', '922', 'checking', 'choices', 'ful', 'abrupt', 'admit', 'core', 'temporary', 'lunchtime/dinner', 'accent', 'stonecrest', 'sparkle', 'stew', 'raging', 'side-dish', 'learning', 'troopers', 'servicing', 'mate', 'breadcrumbs', 'doughy', 'cuticles', 'upholding', '2018', 'pandora', 'shone', 'offseason', 'orthotics', 'session', 'keratin', 'river', 'stayed', 'long', 'optional', 'squirrel', 'stuffed', 'brew', 'oriented', 'wipe', 'creating', 'maid', 'listen', 'fancy', 'cancellation', 'full', 'ship', 'tenderloin', 'bangs', 'houses', 'soon', 'feels', 'childhood', '75', 'stands', 'muscles', 'burden', 'shoot', 'nickel', 'mostly', 'presses', 'abc', 'brining', 'ringer', 'complete', 'crapy', 'wuss', 'covered', 'fantastic', 'ponzu', 'unlimited', 'band', 'cuts', 'settings', 'crescent', 'i', 'investigate', 'soju', 'assured', 'abroad', 'chewy', 'wong', 'iowa', 'cant', 'kfc', 'disorder', 'expect', 'twists', '12:30', 'new/additional', 'patrick', 'mesquite', 'won', 'omit', 'cobbler', 'tho', 'fixed', 'present', 'check-ins', 'morton', 'motion', 'denver', 'holiday', 'gets', 'cons', 'garden', 'randomly', 'resolved', '1may2017', 'thanked', 'trough', 'wo', 'tvs', 'concern', 'curbing', 'stab', 'clerical', 'meeting', 'invaluable', 'supplements', 'indoor', 'pre-packaged', 'overzealous', 'ladies', 'dodgeball', 'march', 'side', 'mandalay', 'you-trim', 'wall', 'policy', 'source', 'politely', 'pizza', 'bunny', 'uni-brow', 'poorly', 'correct', 'itself', 'drained', 'harder', 'upon', 'boost', 'fountain', 'staff', 'arms', 'crushed', 'cosmo', 'strawberry', 'combo-', 'pros', 'sake', 'subpar', 'list', 'formed', '@', 'watch', 'paintings', 'boxes', 'waxing', 'participate', 'generally', 'fucking', 'drama', 'task', 'awakened', 'two-tatted', 'replicate', 'struggle', 'el', 'timbuktu', 'carpe', 'undertone', 'cheaper', 'smelly', 'kale', 'sin', 'ginza', 'separates', 'refrigeration', 'cutest', 'trista', 'y', 'taxi', 'hits', 'downgraded', '8-', '50min', 'corral', 'unavailable', 'fuente', 'extreme', 'repeated', '7pm', 'southeast', 'lots', 'spoiled', 'promise', '2010.', 'artwork', 'decatur', 'chops', 'roped', 'crispy', 'ours', 'guacamole', 'walks', '3-5pm', 'bask', '4:30-6:30', 'tonight', 'zinger', 'customer', 'une', 'spoons', 'lose', 'airbnb', 'laying', 'stacked', 'harbour', 'disgusted', 'hoping', 'gentle', 'crave', 'dragon', 'dot', 'recitation', 'challenging', '7am-10am', 'diagnosing', 'menus', 'aunt', 'bed', 'ever', 'reschedule', 'call', 'men', 'dentist', '.10', 'bottom', 'sold', 'asia', 'liking', 'jamie', 'ganouj', 'moishe', 'refunded', 'saint-paul', 'id', 'bianca', 'sandwich', 'convinced', 'at', 'person', 'hefe', 'orders', 'cartridges', 'worked', 'milestones', 'exploring', 'share', 'firmer', 'cs', 'adamantly', 'ex', 'abfab', 'ribeye', 'trying', 'always', 'crazy', 'some', 'seats', 'rotary', 'leslieville', 'draining', 'crowed', 'views', 'raisin', 'matter', 'walk', 'remove', 'haji', 'rambled', 'so-so', 'nailed', '17', 'narrowed', 'vie', 'fashipn', 'bold', 'jealously', 'chip', 'word', 'significantly', 'yrs', 'elongation', 'spare', 'beets ...

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y, unique_words, weights_matrix):
        self.X = X
        self.y = y
        self.unique_words = unique_words
        self.weights_matrix = weights_matrix

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        document = self.X[idx]
        label = self.y[idx]

        indices = []
        for sentence in document:
            for word in sentence:
                indices.append(self.unique_words.index(word))
        return {
            'input': torch.tensor(indices, dtype=torch.long),
            'label': torch.tensor(label, dtype=torch.float)
        }

def collate_fn(batch):
    inputs = [item['input'] for item in batch]
    labels = [item['label'] for item in batch]

    inputs_padded = pad_sequence(inputs, batch_first=True, padding_value=0)

    return {
        'input': inputs_padded,
        'label': torch.stack(labels)
    }

# %%
class WordAttention(nn.Module):
  def __init__(self,hidden_size, word_embedd_dim) :
    super(WordAttention, self).__init__()
    self.hidden_size = hidden_size
    self.word_embedd_dim= word_embedd_dim
    self.lin1 = nn.Linear(hidden_size,hidden_size)
    self.lin2 =nn.Linear(hidden_size,1,bias = False)
  def forward(self,x):
    u = torch.tanh(self.lin1(x))
    attention = F.softmax(self.lin2(x),dim=1)

    output = torch.sum(attention*x, dim =1)

    return attention, output

class SenAttention(nn.Module):
  def __init__(self, hidden_size, embedding_dim):
    super(SenAttention, self).__init__()
    self.lin1=nn.Linear(hidden_size,hidden_size)
    self.lin2 = nn.Linear(hidden_size,1,bias=False)
  def forward(self, x):
    u = torch.tanh(self.lin1(x))
    attention = F.softmax(self.lin2(u),dim =1)

    output = torch.sum(attention * x, dim =1)

    return attention, output

class WordEncoder(nn.Module):
  def __init__(self, corpus_size, embedding_dim, hidden_size, load_embed=False, weights_matrix=None, trainable_embedding= False):
    super(WordEncoder, self).__init__()

    self.embedding = nn.Embedding(corpus_size, embedding_dim)

    if load_embed and weights_matrix is not None :
      self.embedding.load_state_dict({'weight': torch.tensor(weights_matrix)})

    self.embedding.weight.requires_grad = trainable_embedding
    self.gru = nn.GRU(embedding_dim, hidden_size,2, dropout=0.3, bidirectional= True,batch_first = True)
    self.attention = WordAttention(hidden_size * 2, embedding_dim)
  def forward(self, x):
    embeddings = self.embedding(x)
    out, hidden = self.gru(embeddings)
    attention, out = self.attention(out)
    return out

class HAN(nn.Module):
  def __init__(self, corpus_size, embedding_dim, hidden_size,load_embed= False, weights_matrix=None,trainable_embedding=False):
    super(HAN,self).__init__()

    self.wordEncoder=WordEncoder(corpus_size=corpus_size,embedding_dim=embedding_dim,hidden_size=50, load_embed=True, weights_matrix=weights_matrix, trainable_embedding=True)

    self.sentGRU= nn.GRU(hidden_size*2, hidden_size, bidirectional=True, batch_first=True)
    self.sentence_att = SenAttention(hidden_size * 2, hidden_size)

    self.sigmoid = nn.Sigmoid()
    self.classifer= nn.Linear(hidden_size*2,5)
  def forward(self, x):
    word_output= self.wordEncoder(x)

    sen_out,_ = self.sentGRU(word_output.unsqueeze(1))
    _, sen_output = self.sentence_att(sen_out)

    out = self.classifer(sen_output)
    return F.softmax(out,dim=1)

# %%
batch_size = 16
train_dataset = CustomDataset(X=X_train,y=train_labels,unique_words = unique_words, weights_matrix = weights_matrix)
test_dataset = CustomDataset(X=X_test,y=test_labels,unique_words = unique_words, weights_matrix = weights_matrix)

train_loader = DataLoader(train_dataset, batch_size = batch_size, shuffle = True, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size = len(test_dataset), shuffle = False, collate_fn=collate_fn)

# %%
print(train_loader)
print(train_loader.dataset)
print(train_loader.dataset.__getitem__)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7e2ae00efeb0>
# <__main__.CustomDataset object at 0x7e2ae0dd6b30>
# <bound method CustomDataset.__getitem__ of <__main__.CustomDataset object at 0x7e2ae0dd6b30>>

# %%
def train(model, optim, loss_fn, epochs=50, print_loss=True):
  for epoch in range(50):
    epoch_loss = 0

    model.train()
    for i in train_loader:
      optim.zero_grad()

      output = model(i["input"])
      target = torch.tensor(i["label"], dtype=torch.long)
      target = target.unsqueeze(1)

      loss = loss_fn(output, target.squeeze())
      epoch_loss += loss.item()

      loss.backward()
      optim.step()

    model.eval()
    eval_loss=0
    for i in test_loader:
        output = model(i["input"])
        target = torch.tensor(i["label"], dtype=torch.long)

        loss = loss_fn(output, target)
        eval_loss += loss.item()

    if print_loss:
        if epoch % 10 == 0:
            print("Epoch loss:", round(epoch_loss / len(train_loader), 4))
            print("Eval Loss:", round(eval_loss / len(test_loader), 4))

    print("Eval Loss:", round(eval_loss / len(test_loader), 4))
    return model

# %%
corpus_size, embedding_dim = weights_matrix.shape
han_model = HAN(corpus_size=corpus_size, embedding_dim=embedding_dim, hidden_size=50, load_embed=True, weights_matrix=weights_matrix, trainable_embedding=False)
optim =  torch.optim.Adam(han_model.parameters(), 0.001)
loss_fn = torch.nn.CrossEntropyLoss()
han_model = train(han_model, optim, loss_fn)
# Out:
# <ipython-input-94-c1bce05d9034>:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target = torch.tensor(i["label"], dtype=torch.long)
# Epoch loss: 1.4555
# Eval Loss: 1.5166
# Eval Loss: 1.5166
# <ipython-input-94-c1bce05d9034>:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target = torch.tensor(i["label"], dtype=torch.long)

# %%
def evaluate(model):
  for i in test_loader:
      output = model(i["input"])
      target = i["label"]


  from sklearn.metrics import accuracy_score

  print(accuracy_score(
      target,
      torch.argmax(output, dim=1)
  ))

evaluate(han_model)
# Out:
# 0.38
